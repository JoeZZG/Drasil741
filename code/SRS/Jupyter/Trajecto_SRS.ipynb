# %% [markdown]
# # Software Requirements Specification for Charged Particle Trajectory Simulator
# ## Zhuo Zhang

# %% [markdown]
# # Table of Contents
# <a id="Sec:ToC"></a>
#
# An outline of all sections included in this SRS is recorded here for easy reference.
#
# - [Table of Contents](#Sec:ToC)
# - [Reference Material](#Sec:RefMat)
#  - [Table of Units](#Sec:ToU)
#  - [Table of Symbols](#Sec:ToS)
#  - [Abbreviations and Acronyms](#Sec:TAbbAcc)
# - [Introduction](#Sec:Intro)
#  - [Purpose of Document](#Sec:DocPurpose)
#  - [Scope of Requirements](#Sec:ReqsScope)
#  - [Characteristics of Intended Reader](#Sec:ReaderChars)
#  - [Organization of Document](#Sec:DocOrg)
# - [General System Description](#Sec:GenSysDesc)
#  - [System Context](#Sec:SysContext)
#  - [User Characteristics](#Sec:UserChars)
#  - [System Constraints](#Sec:SysConstraints)
# - [Specific System Description](#Sec:SpecSystDesc)
# - [Problem Description](#Sec:ProbDesc)
#  - [Terminology and Definitions](#Sec:TermDefs)
#  - [Physical System Description](#Sec:PhysSyst)
#  - [Goal Statements](#Sec:GoalStmt)
# - [Solution Characteristics Specification](#Sec:SolCharSpec)
#  - [Assumptions](#Sec:Assumps)
#  - [Theoretical Models](#Sec:TMs)
#  - [General Definitions](#Sec:GDs)
#  - [Data Definitions](#Sec:DDs)
#  - [Instance Models](#Sec:IMs)
#  - [Data Constraints](#Sec:DataConstraints)
#  - [Properties of a Correct Solution](#Sec:CorSolProps)
# - [Requirements](#Sec:Requirements)
#  - [Functional Requirements](#Sec:FRs)
#  - [Non-Functional Requirements](#Sec:NFRs)
# - [Likely Changes](#Sec:LCs)
# - [Unlikely Changes](#Sec:UCs)
# - [Traceability Matrices and Graphs](#Sec:TraceMatrices)
# - [Values of Auxiliary Constants](#Sec:AuxConstants)
# - [References](#Sec:References)
#
# # Reference Material
# <a id="Sec:RefMat"></a>
#
# This section records information for easy reference.
#
# ## Table of Units
# <a id="Sec:ToU"></a>
#
# The unit system used throughout is SI (Système International d'Unités). In addition to the basic units, several derived units are also used. For each unit, the [Table of Units](#Table:ToU) lists the symbol, a description, and the SI name.
#
# <a id="Table:ToU"></a>
#
# |Symbol|Description|SI Name|
# |:--- |:--- |:--- |
# |$C$|electric charge|coulomb|
# |$kg$|mass|kilogram|
# |$m$|length|metre|
# |$N$|force|newton|
# |$s$|time|second|
# |$T$|magnetic flux density|tesla|
#
#
# ## Table of Symbols
# <a id="Sec:ToS"></a>
#
# The symbols used in this document are summarized in the [Table of Symbols](#Table:ToS) along with their units. Throughout the document, symbols in bold will represent vectors, and scalars otherwise. The symbols are listed in alphabetical order. For vector quantities, the units shown are for each component of the vector.
#
# <a id="Table:ToS"></a>
#
# |Symbol|Description|Units|
# |:--- |:--- |:--- |
# |$a_x$|X-acceleration of the particle|$\frac{m}{s^2}$|
# |$a_y$|Y-acceleration of the particle|$\frac{m}{s^2}$|
# |$a(t)$|Acceleration|$\frac{m}{s^2}$|
# |$B_0$|Magnetic flux density in region 0|$T$|
# |$B_1$|Magnetic flux density in region 1|$T$|
# |$B_2$|Magnetic flux density in region 2|$T$|
# |$B_3$|Magnetic flux density in region 3|$T$|
# |$B_4$|Magnetic flux density in region 4|$T$|
# |$B_5$|Magnetic flux density in region 5|$T$|
# |$B$|Magnetic flux density vector|$T$|
# |$B_i$|Magnetic flux density in region i|$T$|
# |$d_orient$|Detector orientation|--|
# |$E_x0$|X-electric field in region 0|$\frac{N}{C}$|
# |$E_x1$|X-electric field in region 1|$\frac{N}{C}$|
# |$E_x2$|X-electric field in region 2|$\frac{N}{C}$|
# |$E_x3$|X-electric field in region 3|$\frac{N}{C}$|
# |$E_x4$|X-electric field in region 4|$\frac{N}{C}$|
# |$E_x5$|X-electric field in region 5|$\frac{N}{C}$|
# |$E_y0$|Y-electric field in region 0|$\frac{N}{C}$|
# |$E_y1$|Y-electric field in region 1|$\frac{N}{C}$|
# |$E_y2$|Y-electric field in region 2|$\frac{N}{C}$|
# |$E_y3$|Y-electric field in region 3|$\frac{N}{C}$|
# |$E_y4$|Y-electric field in region 4|$\frac{N}{C}$|
# |$E_y5$|Y-electric field in region 5|$\frac{N}{C}$|
# |$E$|Electric field vector|$\frac{N}{C}$|
# |$E_i$|Electric field in region i|$\frac{N}{C}$|
# |$F$|Force|$N$|
# |$h$|Region height|$m$|
# |$L_det$|Detector line|--|
# |$m$|Particle mass|$kg$|
# |$m_max$|Maximum particle mass|$kg$|
# |$m_min$|Minimum particle mass|$kg$|
# |$N$|Number of field regions|--|
# |$N_col$|Number of grid columns|--|
# |$p(t)$|Position|$m$|
# |$q$|Particle charge|$C$|
# |$q_max$|Maximum charge magnitude|$C$|
# |$R_i$|Rectangular field region|--|
# |$s$|Dependent variables|$m$|
# |$s_0$|Initial state vector|--|
# |$t$|Time|$s$|
# |$t_final$|Final simulation time|$s$|
# |$t_hit$|Time of detector hit|$s$|
# |$t_max$|Maximum simulation time|$s$|
# |$v_max$|Maximum initial speed|$\frac{m}{s}$|
# |$v_x$|X-velocity of the particle|$\frac{m}{s}$|
# |$v_x0$|Initial x-velocity|$\frac{m}{s}$|
# |$v_y$|Y-velocity of the particle|$\frac{m}{s}$|
# |$v_y0$|Initial y-velocity|$\frac{m}{s}$|
# |$v(t)$|Velocity|$\frac{m}{s}$|
# |$v×B$|Cross product of velocity and magnetic field|--|
# |$w$|Region width|$m$|
# |$x$|X-position of the particle|$m$|
# |$x_0$|Initial x-position|$m$|
# |$x_det$|Detector line x-position|$m$|
# |$x_detMax$|Maximum x-coordinate of detector|$m$|
# |$x_detMin$|Minimum x-coordinate of detector|$m$|
# |$x_grid$|Grid origin x-coordinate|$m$|
# |$x_hit$|X-coordinate of impact point|$m$|
# |$y$|Y-position of the particle|$m$|
# |$y_0$|Initial y-position|$m$|
# |$y_det$|Detector line y-position|$m$|
# |$y_detMax$|Maximum y-coordinate of detector|$m$|
# |$y_detMin$|Minimum y-coordinate of detector|$m$|
# |$y_grid$|Grid origin y-coordinate|$m$|
# |$y_hit$|Y-coordinate of impact point|$m$|
# |$κ$|Charge-to-mass ratio|$\frac{C}{kg}$|
#
#
# ## Abbreviations and Acronyms
# <a id="Sec:TAbbAcc"></a>
#
# <a id="Table:TAbbAcc"></a>
#
# |Abbreviation|Full Form|
# |:--- |:--- |
# |A|Assumption|
# |DD|Data Definition|
# |GD|General Definition|
# |GS|Goal Statement|
# |IM|Instance Model|
# |LC|Likely Change|
# |PS|Physical System Description|
# |R|Requirement|
# |RefBy|Referenced by|
# |Refname|Reference Name|
# |SRS|Software Requirements Specification|
# |TM|Theoretical Model|
# |UC|Unlikely Change|
# |Uncert.|Typical Uncertainty|
#
#
# # Introduction
# <a id="Sec:Intro"></a>
#
# The motion of a charged particle through electromagnetic fields is a fundamental phenomenon arising in particle accelerators, mass spectrometers, and plasma confinement devices. It is therefore useful to have a program to simulate charged particle trajectories in piecewise-uniform fields.
#
# The following section provides an overview of the software requirements specification (SRS) for Charged Particle Trajectory Simulator. This section explains the purpose of this document, the scope of the requirements, the characteristics of the intended reader, and the organization of the document.
#
# ## Purpose of Document
# <a id="Sec:DocPurpose"></a>
#
# The primary purpose of this document is to record the requirements of Trajecto. Goals, assumptions, theoretical models, definitions, and other model derivation information are specified, allowing the reader to fully understand and verify the purpose and scientific basis of Trajecto. With the exception of [system constraints](#Sec:SysConstraints), this SRS will remain abstract, describing what problem is being solved, but not how to solve it.
#
# This document will be used as a starting point for subsequent development phases, including writing the design specification and the software verification and validation plan. The design document will show how the requirements are to be realized, including decisions on the numerical algorithms and programming environment. The verification and validation plan will show the steps that will be used to increase confidence in the software documentation and the implementation. Although the SRS fits in a series of documents that follow the so-called waterfall model, the actual development process is not constrained in any way. Even when the waterfall model is not followed, as Parnas and Clements point out <a href=#parnasClements1986>parnasClements1986</a> , the most logical way to present the documentation is still to "fake" a rational design process.
#
# ## Scope of Requirements
# <a id="Sec:ReqsScope"></a>
#
# The scope of the requirements includes the analysis of two-dimensional charged particle motion in the x-y plane under the Lorentz force.
#
# ## Characteristics of Intended Reader
# <a id="Sec:ReaderChars"></a>
#
# Reviewers of this documentation should have an understanding of undergraduate level physics and undergraduate level calculus. The users of Trajecto can have a lower level of expertise, as explained in [Sec:User Characteristics](#Sec:UserChars).
#
# ## Organization of Document
# <a id="Sec:DocOrg"></a>
#
# The organization of this document follows the template for an SRS for scientific computing software proposed by <a href=#koothoor2013>koothoor2013</a> , <a href=#smithLai2005>smithLai2005</a> , <a href=#smithEtAl2007>smithEtAl2007</a> , and <a href=#smithKoothoor2016>smithKoothoor2016</a> . The presentation follows the standard pattern of presenting goals, theories, definitions, and assumptions. For readers that would like a more bottom up approach, they can start reading the [instance models](#Sec:IMs) and trace back to find any additional information they require.
#
# The [goal statements](#Sec:GoalStmt) are refined to the theoretical models and the [theoretical models](#Sec:TMs) to the [instance models](#Sec:IMs).
#
# # General System Description
# <a id="Sec:GenSysDesc"></a>
#
# This section provides general information about the system. It identifies the interfaces between the system and its environment, describes the user characteristics, and lists the system constraints.
#
# ## System Context
# <a id="Sec:SysContext"></a>
#
# [Fig:sysCtxDiag](#Figure:sysCtxDiag) shows the system context. A rectangle represents the software system (Trajecto), and a circle represents the user providing inputs and receiving outputs.
# <a id="Figure:sysCtxDiag"></a>
# <figure>
# <img src="../../../../datafiles/trajecto/SystemContextFigure.png" alt="System Context" >
# </figure>
#
# The user provides the particle properties, field region grid, per-region electromagnetic fields, detector specification, and simulation time; the software system computes and reports the particle trajectory and detector hit outcome:
#
# ## User Characteristics
# <a id="Sec:UserChars"></a>
#
# The end user of Trajecto should have an understanding of undergraduate-level physics.
#
# ## System Constraints
# <a id="Sec:SysConstraints"></a>
#
# There are no system constraints.
#
# # Specific System Description
# <a id="Sec:SpecSystDesc"></a>
#
# This section first presents the problem description, which gives a high-level view of the problem to be solved. This is followed by the solution characteristics specification, which presents the assumptions, theories, and definitions that are used.
#
# ## Problem Description
# <a id="Sec:ProbDesc"></a>
#
# A system is needed to predict the trajectory of a charged particle moving through piecewise-uniform electric field and magnetic field regions.
#
# ### Terminology and Definitions
# <a id="Sec:TermDefs"></a>
#
# This subsection provides a list of terms that are used in the subsequent sections and their meaning, with the purpose of reducing ambiguity and making it easier to correctly understand the requirements.
#
# - Charged particle: A particle that has a non-zero electric charge and can interact with electric and magnetic fields.
# - Electric field: A physical field that exerts an electric force on charged particles.
# - Magnetic field: A physical field that exerts a magnetic force on moving charged particles.
# - Lorentz force: The force on a charged particle due to electric and magnetic fields.
# - Trajectory: The path traced by a particle over time.
# - Field region: A spatial region in which the electric field and magnetic field are specified, typically treated as uniform within the region.
# - Region grid: A rectangular arrangement of N equal-sized rectangular field regions tiled side-by-side with no gaps or overlaps, whose union forms a single axis-aligned rectangle.
# - Detector line: A line segment (either horizontal or vertical) at a specified location where the particle impact position is recorded.
# - Velocity selector: A configuration of crossed electric and magnetic fields that allows only particles with a particular velocity to pass through without deflection.
# - Cartesian coordinate system: A coordinate system that specifies each point uniquely in a plane by a set of numerical coordinates, which are the signed distances to the point from two fixed perpendicular oriented lines, measured in the same unit of length.
#
# ### Physical System Description
# <a id="Sec:PhysSyst"></a>
#
# The physical system of Trajecto, as shown in [Fig:trajectoPhysSys](#Figure:trajectoPhysSys), includes the following elements:
#
# PS1: A charged particle (the simulated particle)
#
# PS2: The electric field in each field region (may differ between regions)
#
# PS3: The magnetic field perpendicular to the x-y plane in each field region
#
# PS4: The region grid of N equal-sized rectangular field regions
#
# PS5: The detector line (horizontal or vertical) at a specified location
#
# <a id="Figure:trajectoPhysSys"></a>
# <figure>
# <img src="../../../../datafiles/trajecto/trajecto.png" alt="The physical system description" width="60.0%" >
# </figure>
#
# ### Goal Statements
# <a id="Sec:GoalStmt"></a>
#
# Given the particle properties ($q$ and $m$), initial conditions ($x_0$, $y_0$, $v_x0$, $v_y0$), the number of field regions $N$, the per-region fields ($E_x0$, $E_y0$, $B_0$ for each region), the region grid specification ($x_grid$, $y_grid$, $w$, $h$), the detector specification ($d_orient$, $x_det$, $y_det$ and extent), and the simulation time $t_final$, the goal statements are:
#
# <div id=\"predictTrajectory\">
# predictTrajectory: Predict the trajectory of a charged particle under prescribed electric and magnetic fields, computed using [IM:stateEvol](#IM:stateEvol).
#
# </div>
# <div id=\"determineDetectorOutcome\">
# determineDetectorOutcome: Determine impact position and time-of-flight at a specified detector line, computed using [IM:detHit](#IM:detHit).
#
# </div>
#
# ## Solution Characteristics Specification
# <a id="Sec:SolCharSpec"></a>
#
# The instance models that govern Trajecto are presented in the [Instance Model Section](#Sec:IMs). The information to understand the meaning of the instance models and their derivation is also presented, so that the instance models can be verified.
#
# ### Assumptions
# <a id="Sec:Assumps"></a>
#
# This section simplifies the original problem and helps in developing the theoretical models by filling in the missing information for the physical system. The assumptions refine the scope by providing more detail.
#
# <div id=\"piecewiseUniform\">
# piecewiseUniform: The electric and magnetic fields are uniform within each field region and may change only at region boundaries. (RefBy: [DD:fieldsByRegion](#DD:fieldsByRegion).)
#
# </div>
# <div id=\"singleParticle\">
# singleParticle: The particle is treated as a point mass and point charge. (RefBy: [IM:stateEvol](#IM:stateEvol), [TM:lorentzForce](#TM:lorentzForce), [TM:eqnMotion](#TM:eqnMotion), and [A:noInteractions](#noInteractions).)
#
# </div>
# <div id=\"noInteractions\">
# noInteractions: Collisions and particle-particle interactions (including space-charge effects) are neglected; this follows from [A:singleParticle](#singleParticle). (RefBy: [IM:stateEvol](#IM:stateEvol).)
#
# </div>
# <div id=\"prescribedFields\">
# prescribedFields: The electric and magnetic fields are user-specified and remain fixed during the simulation. (RefBy: [TM:lorentzForce](#TM:lorentzForce), [TM:eqnMotion](#TM:eqnMotion), [GD:dyn2D](#GD:dyn2D), [DD:eField](#DD:eField), [DD:fieldsByRegion](#DD:fieldsByRegion), and [DD:bField](#DD:bField).)
#
# </div>
# <div id=\"twoDMotion\">
# twoDMotion: The particle motion is confined to the x-y plane. (RefBy: [GD:vCrossB2D](#GD:vCrossB2D), [IM:stateEvol](#IM:stateEvol), [GD:kin2D](#GD:kin2D), [GD:dyn2D](#GD:dyn2D), [LC:lcExtendTo3D](#lcExtendTo3D), [A:eAxisAligned](#eAxisAligned), and [A:bPerpPlane](#bPerpPlane).)
#
# </div>
# <div id=\"bPerpPlane\">
# bPerpPlane: The magnetic field is perpendicular to the x-y plane, consistent with [A:twoDMotion](#twoDMotion). (RefBy: [GD:vCrossB2D](#GD:vCrossB2D), [GD:dyn2D](#GD:dyn2D), and [DD:bField](#DD:bField).)
#
# </div>
# <div id=\"eAxisAligned\">
# eAxisAligned: The electric field lies in the x-y plane and is aligned with a coordinate axis, consistent with [A:twoDMotion](#twoDMotion). (RefBy: [GD:dyn2D](#GD:dyn2D) and [DD:eField](#DD:eField).)
#
# </div>
# <div id=\"rectRegions\">
# rectRegions: All field regions are axis-aligned rectangles of identical width w and height h. The N regions are tiled adjacently (sharing edges with no gaps or overlaps) so that their union forms a single axis-aligned rectangle. (RefBy: [A:gridLayout](#gridLayout) and [DD:regionRect](#DD:regionRect).)
#
# </div>
# <div id=\"gridLayout\">
# gridLayout: The field regions are numbered 1 through N and arranged in a single row (left-to-right) or single column (bottom-to-top) within the grid rectangle. The arrangement direction is determined by the region grid specification, and region geometry is constrained by [A:rectRegions](#rectRegions). (RefBy: [DD:regionRect](#DD:regionRect).)
#
# </div>
# <div id=\"lineDetector\">
# lineDetector: The detector is modelled as a line segment that is either horizontal or vertical, located at the boundary of or within the region grid. (RefBy: [IM:detHit](#IM:detHit) and [DD:detectorLine](#DD:detectorLine).)
#
# </div>
# <div id=\"fullDetection\">
# fullDetection: The detector line is sufficiently long to record the impact point for any trajectory within the scope of the simulation. (RefBy: [IM:detHit](#IM:detHit).)
#
# </div>
# <div id=\"lorentzOnly\">
# lorentzOnly: The particle dynamics are governed only by the Lorentz force; all other forces are neglected. (RefBy: [IM:stateEvol](#IM:stateEvol), [TM:eqnMotion](#TM:eqnMotion), and [UC:ucLorentzForce](#ucLorentzForce).)
#
# </div>
#
# ### Theoretical Models
# <a id="Sec:TMs"></a>
#
# This section focuses on the general equations and laws that Trajecto is based on.
# <br>
# <a id="TM:velocity"></a>
# <table class=\"tdefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>TM:velocity</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Velocity
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\symbf{v}\text{(}t\text{)}=\frac{\,d\symbf{p}\text{(}t\text{)}}{\,dt}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$v(t)$ is the velocity ($\frac{m}{s}$)</li>
# <li>$t$ is the time ($s$)</li>
# <li>$p(t)$ is the position ($m$)</li>
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# <a href=#velocityWiki>velocityWiki</a>
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [GD:kin2D](#GD:kin2D)
# </td>
# </tr>
# </table>
# <br>
# <a id="TM:acceleration"></a>
# <table class=\"tdefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>TM:acceleration</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Acceleration
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\symbf{a}\text{(}t\text{)}=\frac{\,d\symbf{v}\text{(}t\text{)}}{\,dt}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$a(t)$ is the acceleration ($\frac{m}{s^2}$)</li>
# <li>$t$ is the time ($s$)</li>
# <li>$v(t)$ is the velocity ($\frac{m}{s}$)</li>
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# <a href=#accelerationWiki>accelerationWiki</a>
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
#
# </td>
# </tr>
# </table>
# <br>
# <a id="TM:lorentzForce"></a>
# <table class=\"tdefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>TM:lorentzForce</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Lorentz force law
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\symbf{F}=q\,\left(\symbf{E}+\symbf{v}\text{×}\symbf{B}\right)$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$F$ is the force ($N$)</li>
# <li>$q$ is the particle charge ($C$)</li>
# <li>$E$ is the electric field vector ($\frac{N}{C}$)</li>
# <li>$v×B$ is the cross product of velocity and magnetic field (Unitless)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# The electromagnetic force on a charged particle is F = q*(E + v×B), where $F$ is the total force vector, $q$ is the particle charge, $E$ is the electric field vector, and $v×B$ is the cross product of velocity and magnetic flux density.. For 2D planar motion with an out-of-plane magnetic field, this reduces to the component equations derived in the general definitions. Assumes [A:singleParticle](#singleParticle), [A:prescribedFields](#prescribedFields).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [TM:eqnMotion](#TM:eqnMotion) and [GD:dyn2D](#GD:dyn2D)
# </td>
# </tr>
# </table>
# <br>
# <a id="TM:eqnMotion"></a>
# <table class=\"tdefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>TM:eqnMotion</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Equation of motion under electromagnetic fields
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $${a_{\text{x}}}=\frac{q}{m}\,\left({E_{\text{x}0}}+{v_{\text{y}}}\,{B_{0}}\right)$$
# $${a_{\text{y}}}=\frac{q}{m}\,\left({E_{\text{y}0}}-{v_{\text{x}}}\,{B_{0}}\right)$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$a_x$ is the x-acceleration of the particle ($\frac{m}{s^2}$)</li>
# <li>$q$ is the particle charge ($C$)</li>
# <li>$m$ is the particle mass ($kg$)</li>
# <li>$E_x0$ is the x-electric field in region 0 ($\frac{N}{C}$)</li>
# <li>$v_y$ is the y-velocity of the particle ($\frac{m}{s}$)</li>
# <li>$B_0$ is the magnetic flux density in region 0 ($T$)</li>
#
# <li>$a_y$ is the y-acceleration of the particle ($\frac{m}{s^2}$)</li>
# <li>$q$ is the particle charge ($C$)</li>
# <li>$m$ is the particle mass ($kg$)</li>
# <li>$E_y0$ is the y-electric field in region 0 ($\frac{N}{C}$)</li>
# <li>$v_x$ is the x-velocity of the particle ($\frac{m}{s}$)</li>
# <li>$B_0$ is the magnetic flux density in region 0 ($T$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# Combining Newton's second law with the Lorentz force law, ([TM:lorentzForce](#TM:lorentzForce)), the equations of motion for each velocity component are obtained. The quantity q/m is the charge-to-mass ratio. Assumes [A:singleParticle](#singleParticle), [A:prescribedFields](#prescribedFields), [A:lorentzOnly](#lorentzOnly).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [GD:dyn2D](#GD:dyn2D)
# </td>
# </tr>
# </table>
#
# ### General Definitions
# <a id="Sec:GDs"></a>
#
# This section collects the laws and equations that will be used to build the instance models.
# <br>
# <a id="GD:kin2D"></a>
# <table class=\"gdefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>GD:kin2D</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Two-dimensional kinematics in Cartesian coordinates
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# $\frac{m}{s}$
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\frac{\,dx}{\,dt}={v_{\text{x}}}\land{}\frac{\,dy}{\,dt}={v_{\text{y}}}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$t$ is the time ($s$)</li>
# <li>$x$ is the x-position of the particle ($m$)</li>
# <li>$v_x$ is the x-velocity of the particle ($\frac{m}{s}$)</li>
# <li>$y$ is the y-position of the particle ($m$)</li>
# <li>$v_y$ is the y-velocity of the particle ($\frac{m}{s}$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# The planar motion assumption ([A:twoDMotion](#twoDMotion)) allows the particle position to be represented by $x$ and $y$ with velocity components $v_x$ and $v_y$ respectively. Velocity is defined in [TM:velocity](#TM:velocity)..
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [IM:stateEvol](#IM:stateEvol)
# </td>
# </tr>
# </table>
# <br>
# <a id="GD:vCrossB2D"></a>
# <table class=\"gdefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>GD:vCrossB2D</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Cross product v x B for out-of-plane magnetic field
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# $\frac{N}{C}$
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\symbf{v}\text{×}\symbf{B}=\begin{bmatrix}                           {v_{\text{y}}}\,{B_{0}} & -{v_{\text{x}}}\,{B_{0}} & 0                           \end{bmatrix}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$v×B$ is the cross product of velocity and magnetic field (Unitless)</li>
# <li>$v_y$ is the y-velocity of the particle ($\frac{m}{s}$)</li>
# <li>$B_0$ is the magnetic flux density in region 0 ($T$)</li>
# <li>$v_x$ is the x-velocity of the particle ($\frac{m}{s}$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# Under planar motion ([A:twoDMotion](#twoDMotion)) and an out-of-plane magnetic field ([A:bPerpPlane](#bPerpPlane)), the velocity has the form v(t) = (vx(t), vy(t), 0) and the magnetic field has the form B = (0, 0, B). The cross product then reduces to the stated component form..
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [GD:dyn2D](#GD:dyn2D)
# </td>
# </tr>
# </table>
# <br>
# <a id="GD:dyn2D"></a>
# <table class=\"gdefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>GD:dyn2D</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Two-dimensional equations of motion under E and B
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# $\frac{m}{s^2}$
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\frac{\,d{v_{\text{x}}}}{\,dt}=κ\,\left({E_{\text{x}0}}+{v_{\text{y}}}\,{B_{0}}\right)\land{}\frac{\,d{v_{\text{y}}}}{\,dt}=κ\,\left({E_{\text{y}0}}-{v_{\text{x}}}\,{B_{0}}\right)$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$t$ is the time ($s$)</li>
# <li>$v_x$ is the x-velocity of the particle ($\frac{m}{s}$)</li>
# <li>$κ$ is the charge-to-mass ratio ($\frac{C}{kg}$)</li>
# <li>$E_x0$ is the x-electric field in region 0 ($\frac{N}{C}$)</li>
# <li>$v_y$ is the y-velocity of the particle ($\frac{m}{s}$)</li>
# <li>$B_0$ is the magnetic flux density in region 0 ($T$)</li>
# <li>$E_y0$ is the y-electric field in region 0 ($\frac{N}{C}$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# Assuming planar motion ([A:twoDMotion](#twoDMotion)), prescribed fields ([A:prescribedFields](#prescribedFields)), out-of-plane magnetic field ([A:bPerpPlane](#bPerpPlane)), and axis-aligned electric field ([A:eAxisAligned](#eAxisAligned)). Here $κ$ = q/m is the charge-to-mass ratio defined in [DD:qOverm](#DD:qOverm). The equations are obtained from [TM:lorentzForce](#TM:lorentzForce) and [TM:eqnMotion](#TM:eqnMotion) by applying [GD:vCrossB2D](#GD:vCrossB2D).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [IM:stateEvol](#IM:stateEvol)
# </td>
# </tr>
# </table>
#
# ### Data Definitions
# <a id="Sec:DDs"></a>
#
# This section collects and defines all the data needed to build the instance models.
# <br>
# <a id="DD:qOverm"></a>
# <table class=\"ddefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>DD:qOverm</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Charge-to-mass ratio
# </td>
# </tr>
# <tr>
# <th>Symbol</th>
# <td>
#
# $κ$
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# $\frac{C}{kg}$
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$κ=\frac{q}{m}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$κ$ is the charge-to-mass ratio ($\frac{C}{kg}$)</li>
# <li>$q$ is the particle charge ($C$)</li>
# <li>$m$ is the particle mass ($kg$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# $q$ is the particle charge and $m$ is the particle mass. The ratio $κ$ is used to simplify the equations of motion.
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [IM:stateEvol](#IM:stateEvol) and [GD:dyn2D](#GD:dyn2D)
# </td>
# </tr>
# </table>
# <br>
# <a id="DD:initState"></a>
# <table class=\"ddefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>DD:initState</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Initial state vector
# </td>
# </tr>
# <tr>
# <th>Symbol</th>
# <td>
#
# $s_0$
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# Unitless
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $${s_{0}}=\begin{bmatrix}        {x_{0}} & {y_{0}} & {v_{\text{x}0}} & {v_{\text{y}0}}        \end{bmatrix}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$s_0$ is the initial state vector (Unitless)</li>
# <li>$x_0$ is the initial x-position ($m$)</li>
# <li>$y_0$ is the initial y-position ($m$)</li>
# <li>$v_x0$ is the initial x-velocity ($\frac{m}{s}$)</li>
# <li>$v_y0$ is the initial y-velocity ($\frac{m}{s}$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# $x_0$, $y_0$ are the initial position components (m) and $v_x0$, $v_y0$ are the initial velocity components (m/s).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [IM:stateEvol](#IM:stateEvol)
# </td>
# </tr>
# </table>
# <br>
# <a id="DD:eField"></a>
# <table class=\"ddefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>DD:eField</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Electric field vector
# </td>
# </tr>
# <tr>
# <th>Symbol</th>
# <td>
#
# $E$
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# $\frac{N}{C}$
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\symbf{E}=\begin{bmatrix}          {E_{\text{x}0}} & {E_{\text{y}0}} & 0          \end{bmatrix}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$E$ is the electric field vector ($\frac{N}{C}$)</li>
# <li>$E_x0$ is the x-electric field in region 0 ($\frac{N}{C}$)</li>
# <li>$E_y0$ is the y-electric field in region 0 ($\frac{N}{C}$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# $E$ is the electric field vector. $E_x0$ and $E_y0$ are the in-plane components (N/C). The out-of-plane component is zero by [A:eAxisAligned](#eAxisAligned), and the fields are user-specified per [A:prescribedFields](#prescribedFields).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
#
# </td>
# </tr>
# </table>
# <br>
# <a id="DD:bField"></a>
# <table class=\"ddefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>DD:bField</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Magnetic flux density vector
# </td>
# </tr>
# <tr>
# <th>Symbol</th>
# <td>
#
# $B$
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# $T$
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\symbf{B}=\begin{bmatrix}          0 & 0 & {B_{0}}          \end{bmatrix}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$B$ is the magnetic flux density vector ($T$)</li>
# <li>$B_0$ is the magnetic flux density in region 0 ($T$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# $B$ is the magnetic flux density vector. $B_0$ is the out-of-plane (z) component (T). The in-plane components are zero by [A:bPerpPlane](#bPerpPlane); fields are fixed by [A:prescribedFields](#prescribedFields).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
#
# </td>
# </tr>
# </table>
# <br>
# <a id="DD:regionRect"></a>
# <table class=\"ddefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>DD:regionRect</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Rectangular field region
# </td>
# </tr>
# <tr>
# <th>Symbol</th>
# <td>
#
# $R_i$
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# Unitless
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $${R_{i}}=\begin{bmatrix}        {x_{\text{grid}}} & {y_{\text{grid}}} & w & h        \end{bmatrix}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$R_i$ is the rectangular field region (Unitless)</li>
# <li>$x_grid$ is the grid origin x-coordinate ($m$)</li>
# <li>$y_grid$ is the grid origin y-coordinate ($m$)</li>
# <li>$w$ is the region width ($m$)</li>
# <li>$h$ is the region height ($m$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# Each field region R_i (for i = 1 .. $N$ ) is an axis-aligned rectangle of width $w$ and height $h$. The equation above lists the grid parameters that define each region. For a row layout (regions tiled left-to-right): R_i = [x_grid + (i-1)*w, x_grid + i*w] x [y_grid, y_grid + h]. For a column layout (regions tiled bottom-to-top): R_i = [x_grid, x_grid + w] x [y_grid + (i-1)*h, y_grid + i*h]. The grid origin ($x_grid$, $y_grid$) anchors region 1, per [A:rectRegions](#rectRegions) and [A:gridLayout](#gridLayout).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [FR:Build-Region-Grid](#buildRegionGrid) and [DD:fieldsByRegion](#DD:fieldsByRegion)
# </td>
# </tr>
# </table>
# <br>
# <a id="DD:fieldsByRegion"></a>
# <table class=\"ddefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>DD:fieldsByRegion</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Electric field in region i
# </td>
# </tr>
# <tr>
# <th>Symbol</th>
# <td>
#
# $E_i$
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# $\frac{N}{C}$
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $${\symbf{E}_{i}}=\begin{bmatrix}                {E_{\text{x}0}} & {E_{\text{y}0}} & {B_{0}}                \end{bmatrix}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$E_i$ is the electric field in region i ($\frac{N}{C}$)</li>
# <li>$E_x0$ is the x-electric field in region 0 ($\frac{N}{C}$)</li>
# <li>$E_y0$ is the y-electric field in region 0 ($\frac{N}{C}$)</li>
# <li>$B_0$ is the magnetic flux density in region 0 ($T$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# Each region R_i has its own independently specified electric field $E_i$ = (Ex_i, Ey_i, 0) and magnetic flux density $B_i$ = (0, 0, B_i). The fields are constant within each region per [A:piecewiseUniform](#piecewiseUniform). The active fields at time t are determined by which region R_i ([DD:regionRect](#DD:regionRect)) contains the particle position (x(t), y(t)). If the particle is outside all defined regions, the fields default to zero and the particle undergoes free (force-free) motion. The per-region values (Ex_i, Ey_i, B_i) are user-specified inputs per [A:prescribedFields](#prescribedFields).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [IM:stateEvol](#IM:stateEvol) and [FR:Lookup-Active-Region](#lookupActiveRegion)
# </td>
# </tr>
# </table>
# <br>
# <a id="DD:detectorLine"></a>
# <table class=\"ddefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>DD:detectorLine</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Detector line
# </td>
# </tr>
# <tr>
# <th>Symbol</th>
# <td>
#
# $L_det$
# </td>
# </tr>
# <tr>
# <th>Units</th>
# <td>
#
# Unitless
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $${L_{\text{det}}}=\begin{bmatrix}                 {d_{\text{orient}}} & {x_{\text{det}}} & {y_{\text{det}}} & {y_{\text{detMin}}} & {y_{\text{detMax}}} & {x_{\text{detMin}}} & {x_{\text{detMax}}}                 \end{bmatrix}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$L_det$ is the detector line (Unitless)</li>
# <li>$d_orient$ is the detector orientation (Unitless)</li>
# <li>$x_det$ is the detector line x-position ($m$)</li>
# <li>$y_det$ is the detector line y-position ($m$)</li>
# <li>$y_detMin$ is the minimum y-coordinate of detector ($m$)</li>
# <li>$y_detMax$ is the maximum y-coordinate of detector ($m$)</li>
# <li>$x_detMin$ is the minimum x-coordinate of detector ($m$)</li>
# <li>$x_detMax$ is the maximum x-coordinate of detector ($m$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# $L_det$ is the detector line segment. When $d_orient$ = 0 (vertical), the detector is L_det is the set of (x,y) such that x = x_det and y in [y_min(det), y_max(det)]. When $d_orient$ = 1 (horizontal), the detector is L_det is the set of (x,y) such that y = y_det and x in [x_min(det), x_max(det)]. The detector orientation and bounds are user-specified, per [A:lineDetector](#lineDetector).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [IM:detHit](#IM:detHit)
# </td>
# </tr>
# </table>
#
# ### Instance Models
# <a id="Sec:IMs"></a>
#
# This section transforms the problem defined in the [problem description](#Sec:ProbDesc) into one which is expressed in mathematical terms. It uses concrete symbols defined in the [data definitions](#Sec:DDs) to replace the abstract symbols in the models identified in [theoretical models](#Sec:TMs) and [general definitions](#Sec:GDs).
# <br>
# <a id="IM:stateEvol"></a>
# <table class=\"idefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>IM:stateEvol</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# Particle state evolution in the x-y plane
# </td>
# </tr>
# <tr>
# <th>Input</th>
# <td>
#
# $m$, $q$, $x_0$, $y_0$, $v_x0$, $v_y0$, $E_x0$, $E_y0$, $B_0$, $t_final$
# </td>
# </tr>
# <tr>
# <th>Output</th>
# <td>
#
# $x$
# </td>
# </tr>
# <tr>
# <th>Input Constraints</th>
# <td>
# </td>
# </tr>
# <tr>
# <th>Output Constraints</th>
# <td>
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$\frac{\,dx}{\,dt}={v_{\text{x}}}\land{}\frac{\,dy}{\,dt}={v_{\text{y}}}\land{}\frac{\,d{v_{\text{x}}}}{\,dt}=κ\,\left({E_{\text{x}0}}+{v_{\text{y}}}\,{B_{0}}\right)\land{}\frac{\,d{v_{\text{y}}}}{\,dt}=κ\,\left({E_{\text{y}0}}-{v_{\text{x}}}\,{B_{0}}\right)$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$t$ is the time ($s$)</li>
# <li>$x$ is the x-position of the particle ($m$)</li>
# <li>$v_x$ is the x-velocity of the particle ($\frac{m}{s}$)</li>
# <li>$y$ is the y-position of the particle ($m$)</li>
# <li>$v_y$ is the y-velocity of the particle ($\frac{m}{s}$)</li>
# <li>$κ$ is the charge-to-mass ratio ($\frac{C}{kg}$)</li>
# <li>$E_x0$ is the x-electric field in region 0 ($\frac{N}{C}$)</li>
# <li>$B_0$ is the magnetic flux density in region 0 ($T$)</li>
# <li>$E_y0$ is the y-electric field in region 0 ($\frac{N}{C}$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# Bold symbols denote vectors; the state vector s(t) = (x(t), y(t), vx(t), vy(t)) collects position and velocity components. $κ$ = q/m is the charge-to-mass ratio ([DD:qOverm](#DD:qOverm)). The initial condition is s(0) = (x0, y0, v0x, v0y) ([DD:initState](#DD:initState)). The fields (Ex(t), Ey(t)) and B(t) are determined by which region R_i contains (x(t), y(t)) at time t ([DD:fieldsByRegion](#DD:fieldsByRegion)). If (x(t), y(t)) lies outside all defined regions, the fields default to zero and the particle undergoes free (force-free) motion. The model is derived by combining [GD:kin2D](#GD:kin2D) and [GD:dyn2D](#GD:dyn2D). Applicable assumptions: [A:singleParticle](#singleParticle), [A:noInteractions](#noInteractions), [A:twoDMotion](#twoDMotion) and [A:lorentzOnly](#lorentzOnly).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [IM:detHit](#IM:detHit), [FR:Report-Outputs](#reportOutputs), [GS:predictTrajectory](#predictTrajectory), and [FR:Compute-Trajectory](#computeTraj)
# </td>
# </tr>
# </table>
# <br>
# <a id="IM:detHit"></a>
# <table class=\"idefn\">
# <tr>
# <th>Refname</th>
# <td>
# <b>IM:detHit</b>
# </td>
# </tr>
# <tr>
# <th>Label</th>
# <td>
#
# First detector intersection (hit time and hit location)
# </td>
# </tr>
# <tr>
# <th>Input</th>
# <td>
#
# $d_orient$, $x_det$, $y_det$, $y_detMin$, $y_detMax$, $x_detMin$, $x_detMax$, $t_final$, $x$, $y$
# </td>
# </tr>
# <tr>
# <th>Output</th>
# <td>
#
# $t_hit$
# </td>
# </tr>
# <tr>
# <th>Input Constraints</th>
# <td>
# </td>
# </tr>
# <tr>
# <th>Output Constraints</th>
# <td>
# </td>
# </tr>
# <tr>
# <th>Equation</th>
# <td>
# $$x={x_{\text{det}}}\land{}{y_{\text{hit}}}\geq{}{y_{\text{detMin}}}\land{}{y_{\text{hit}}}\leq{}{y_{\text{detMax}}}\lor{}y={y_{\text{det}}}\land{}{x_{\text{hit}}}\geq{}{x_{\text{detMin}}}\land{}{x_{\text{hit}}}\leq{}{x_{\text{detMax}}}$$
# </td>
# </tr>
# <tr>
# <th>Description</th>
# <td>
#
# <li>$x$ is the x-position of the particle ($m$)</li>
# <li>$x_det$ is the detector line x-position ($m$)</li>
# <li>$y_hit$ is the y-coordinate of impact point ($m$)</li>
# <li>$y_detMin$ is the minimum y-coordinate of detector ($m$)</li>
# <li>$y_detMax$ is the maximum y-coordinate of detector ($m$)</li>
# <li>$y$ is the y-position of the particle ($m$)</li>
# <li>$y_det$ is the detector line y-position ($m$)</li>
# <li>$x_hit$ is the x-coordinate of impact point ($m$)</li>
# <li>$x_detMin$ is the minimum x-coordinate of detector ($m$)</li>
# <li>$x_detMax$ is the maximum x-coordinate of detector ($m$)</li>
# </td>
# </tr>
# <tr>
# <th>Notes</th>
# <td>
#
# The detector is modelled as a line segment that may be vertical or horizontal, selected by the orientation flag $d_orient$ ([DD:detectorLine](#DD:detectorLine)). Vertical case (D = 0): the detector is at x = $x_det$ with y-bounds [$y_detMin$, $y_detMax$]. The hit condition is x(t) = x_det and y(t) in [y_min, y_max]. Horizontal case (D = 1): the detector is at y = $y_det$ with x-bounds [$x_detMin$, $x_detMax$]. The hit condition is y(t) = y_det and x(t) in [x_min, x_max]. In both cases, $t_hit$ is the minimum t in [0, $t_final$] satisfying the condition. If no such t exists, $t_hit$ is set to -1 as a sentinel value indicating no hit, and the hit coordinates are undefined. The trajectory (x(t), y(t)) is provided by [IM:stateEvol](#IM:stateEvol). Applicable assumptions: [A:fullDetection](#fullDetection) and [A:lineDetector](#lineDetector).
# </td>
# </tr>
# <tr>
# <th>Source</th>
# <td>
#
# --
# </td>
# </tr>
# <tr>
# <th>RefBy</th>
# <td>
#
# [FR:Report-Outputs](#reportOutputs) and [GS:determineDetectorOutcome](#determineDetectorOutcome)
# </td>
# </tr>
# </table>
#
# ### Data Constraints
# <a id="Sec:DataConstraints"></a>
#
# The [Input Data Constraints Table](#Table:InDataConstraints) shows the data constraints on the input variables. The column for physical constraints gives the physical limitations on the range of values that can be taken by the variable. The uncertainty column provides an estimate of the confidence with which the physical quantities can be measured. This information would be part of the input if one were performing an uncertainty quantification exercise. The constraints are conservative to give the user of the model the flexibility to experiment with unusual situations. The column of typical values is intended to provide a feel for a common scenario.
#
# <a id="Table:InDataConstraints"></a>
#
# |Var|Physical Constraints|Software Constraints|Typical Value|Uncert.|
# |:--- |:--- |:--- |:--- |:--- |
# |$d_orient$|--|$0&thinsp;&le;&thinsp;d_orient&thinsp;&le;&thinsp;1$|$0$|0.0$%$|
# |$h$|$h&thinsp;&gt;&thinsp;0$|--|$0.1$ $m$|0.0$%$|
# |$m$|$m&thinsp;&gt;&thinsp;0$|$m_min&thinsp;&le;&thinsp;m&thinsp;&le;&thinsp;m_max$|$911.0&sdot;10^-33$ $kg$|10.0$%$|
# |$N$|$N&thinsp;&gt;&thinsp;0$|--|$1$|0.0$%$|
# |$N_col$|$N_col&thinsp;&gt;&thinsp;0$|--|$1$|0.0$%$|
# |$q$|--|$-q_max&thinsp;&le;&thinsp;q&thinsp;&le;&thinsp;q_max$|$160.0&sdot;10^-21$ $C$|10.0$%$|
# |$t_final$|$t_final&thinsp;&gt;&thinsp;0$|$t_final&thinsp;&le;&thinsp;t_max$|$1.0&sdot;10^-6$ $s$|0.0$%$|
# |$v_x0$|--|$-v_max&thinsp;&le;&thinsp;v_x0&thinsp;&le;&thinsp;v_max$|$1.0&sdot;10^6$ $\frac{m}{s}$|10.0$%$|
# |$v_y0$|--|$-v_max&thinsp;&le;&thinsp;v_y0&thinsp;&le;&thinsp;v_max$|$0$ $\frac{m}{s}$|10.0$%$|
# |$w$|$w&thinsp;&gt;&thinsp;0$|--|$0.1$ $m$|0.0$%$|
# |$x_0$|--|--|$0$ $m$|0.0$%$|
# |$x_det$|--|--|$0.1$ $m$|0.0$%$|
# |$x_detMax$|--|--|$0.1$ $m$|0.0$%$|
# |$x_detMin$|--|--|$0$ $m$|0.0$%$|
# |$x_grid$|--|--|$0$ $m$|0.0$%$|
# |$y_0$|--|--|$0$ $m$|0.0$%$|
# |$y_det$|--|--|$0$ $m$|0.0$%$|
# |$y_detMax$|--|--|$0.05$ $m$|0.0$%$|
# |$y_detMin$|--|--|$0.0-5$ $m$|0.0$%$|
# |$y_grid$|--|--|$0$ $m$|0.0$%$|
#
#
# ### Properties of a Correct Solution
# <a id="Sec:CorSolProps"></a>
#
# The [Output Data Constraints Table](#Table:OutDataConstraints) shows the data constraints on the output variables. The column for physical constraints gives the physical limitations on the range of values that can be taken by the variable.
#
# <a id="Table:OutDataConstraints"></a>
#
# |Var|
# |:--- |
# |$s$|
# |$t_hit$|
# |$y_hit$|
# |$x_hit$|
#
#
# For a pure magnetic field (no electric field, i.e., Ex = Ey = 0), the speed of the particle must remain constant over time, since the magnetic force is always perpendicular to the velocity and therefore does no work on the particle. A correct solution must satisfy |v(t)| = |v(0)| for all times t in the simulation.
#
# When the electric field is non-zero, the work-energy theorem requires that the change in kinetic energy equals the work done by the electric force: delta_KE = q * Ex * delta_x + q * Ey * delta_y. A correct solution must respect this energy balance over each time step.
#
# In the absence of all fields (Ex = Ey = 0 and B = 0), Newton's first law requires that the particle travel in a straight line at constant velocity. A correct solution must show no change in either velocity component and linear growth in both position components.
#
# When the particle crosses from region R_i to region R_j, the position and velocity must be continuous at the boundary. Only the acceleration changes (due to the different fields in the new region). A correct solution must preserve continuity of the state vector at every region boundary crossing..
#
# # Requirements
# <a id="Sec:Requirements"></a>
#
# This section provides the functional requirements, the tasks and behaviours that the software is expected to complete, and the non-functional requirements, the qualities that the software is expected to exhibit.
#
# ## Functional Requirements
# <a id="Sec:FRs"></a>
#
# This section provides the functional requirements, the tasks and behaviours that the software is expected to complete.
#
# <div id=\"inputValues\">
# Input-Values: Input the values from [Tab:ReqInputs](#Table:ReqInputs).
#
# </div>
# <div id=\"echoInputs\">
# Echo-Inputs: Echo the given inputs.
#
# </div>
# <div id=\"buildRegionGrid\">
# Build-Region-Grid: Construct the N field regions from the grid origin, region dimensions (w, h), and region count N, and assign each region its specified (Ex_i, Ey_i, B_i) ([DD:regionRect](#DD:regionRect)).
#
# </div>
# <div id=\"lookupActiveRegion\">
# Lookup-Active-Region: At each simulation time-step, determine which region R_i contains the particle position (x(t), y(t)) and apply the corresponding fields. If the particle is outside all regions, apply zero fields ([DD:fieldsByRegion](#DD:fieldsByRegion)).
#
# </div>
# <div id=\"computeTraj\">
# Compute-Trajectory: Compute the trajectory of the charged particle using the equations of motion derived from the Lorentz force ([IM:stateEvol](#IM:stateEvol)).
#
# </div>
# <div id=\"reportOutputs\">
# Report-Outputs: Report the final position, velocity, and whether the particle reaches the detector line, based on [IM:stateEvol](#IM:stateEvol) and [IM:detHit](#IM:detHit).
#
# </div>
#
# <a id="Table:ReqInputs"></a>
#
# |Symbol|Description|Units|
# |:--- |:--- |:--- |
# |$B_0$|Magnetic flux density in region 0|$T$|
# |$B_1$|Magnetic flux density in region 1|$T$|
# |$B_2$|Magnetic flux density in region 2|$T$|
# |$B_3$|Magnetic flux density in region 3|$T$|
# |$B_4$|Magnetic flux density in region 4|$T$|
# |$B_5$|Magnetic flux density in region 5|$T$|
# |$d_orient$|Detector orientation|--|
# |$E_x0$|X-electric field in region 0|$\frac{N}{C}$|
# |$E_x1$|X-electric field in region 1|$\frac{N}{C}$|
# |$E_x2$|X-electric field in region 2|$\frac{N}{C}$|
# |$E_x3$|X-electric field in region 3|$\frac{N}{C}$|
# |$E_x4$|X-electric field in region 4|$\frac{N}{C}$|
# |$E_x5$|X-electric field in region 5|$\frac{N}{C}$|
# |$E_y0$|Y-electric field in region 0|$\frac{N}{C}$|
# |$E_y1$|Y-electric field in region 1|$\frac{N}{C}$|
# |$E_y2$|Y-electric field in region 2|$\frac{N}{C}$|
# |$E_y3$|Y-electric field in region 3|$\frac{N}{C}$|
# |$E_y4$|Y-electric field in region 4|$\frac{N}{C}$|
# |$E_y5$|Y-electric field in region 5|$\frac{N}{C}$|
# |$h$|Region height|$m$|
# |$m$|Particle mass|$kg$|
# |$N$|Number of field regions|--|
# |$N_col$|Number of grid columns|--|
# |$q$|Particle charge|$C$|
# |$t_final$|Final simulation time|$s$|
# |$v_x0$|Initial x-velocity|$\frac{m}{s}$|
# |$v_y0$|Initial y-velocity|$\frac{m}{s}$|
# |$w$|Region width|$m$|
# |$x_0$|Initial x-position|$m$|
# |$x_det$|Detector line x-position|$m$|
# |$x_detMax$|Maximum x-coordinate of detector|$m$|
# |$x_detMin$|Minimum x-coordinate of detector|$m$|
# |$x_grid$|Grid origin x-coordinate|$m$|
# |$y_0$|Initial y-position|$m$|
# |$y_det$|Detector line y-position|$m$|
# |$y_detMax$|Maximum y-coordinate of detector|$m$|
# |$y_detMin$|Minimum y-coordinate of detector|$m$|
# |$y_grid$|Grid origin y-coordinate|$m$|
#
#
# ## Non-Functional Requirements
# <a id="Sec:NFRs"></a>
#
# This section provides the non-functional requirements, the qualities that the software is expected to exhibit.
#
# <div id=\"correct\">
# Correctness: The outputs of the code have the [properties of a correct solution](#Sec:CorSolProps).
#
# </div>
# <div id=\"maintainable\">
# Maintainability: If a likely change is made to the finished software, it will take at most 10$%$ of the original development time, assuming the same development resources are available.
#
# </div>
# <div id=\"portable\">
# Portability: The code shall be portable to multiple environments, particularly Windows, Mac OSX, and Linux.
#
# </div>
#
# # Likely Changes
# <a id="Sec:LCs"></a>
#
# This section lists the likely changes (LC) to be made to the software.
#
# <div id=\"lcExtendTo3D\">
# lcExtendTo3D: [A:twoDMotion](#twoDMotion) - extend Trajecto to support three-dimensional (3D) motion, including a z-component of position, velocity, acceleration, electric field, and magnetic field.
#
# </div>
#
# # Unlikely Changes
# <a id="Sec:UCs"></a>
#
# This section lists the unlikely changes (UC) to be made to the software.
#
# <div id=\"ucLorentzForce\">
# ucLorentzForce: [A:lorentzOnly](#lorentzOnly) - the Lorentz force law is a well-established physical principle and is unlikely to change.
#
# </div>
#
# # Traceability Matrices and Graphs
# <a id="Sec:TraceMatrices"></a>
#
# The purpose of the traceability matrices is to provide easy references on what has to be additionally modified if a certain component is changed. Every time a component is changed, the items in the column of that component that are marked with an "X" should be modified as well. [Tab:TraceMatAvsA](#Table:TraceMatAvsA) shows the dependencies of the assumptions on each other. [Tab:TraceMatAvsAll](#Table:TraceMatAvsAll) shows the dependencies of the data definitions, theoretical models, general definitions, instance models, requirements, likely changes, and unlikely changes on the assumptions. [Tab:TraceMatRefvsRef](#Table:TraceMatRefvsRef) shows the dependencies of the data definitions, theoretical models, general definitions, and instance models on each other. [Tab:TraceMatAllvsR](#Table:TraceMatAllvsR) shows the dependencies of the requirements and goal statements on the data definitions, theoretical models, general definitions, and instance models.
#
# <a id="Table:TraceMatAvsA"></a>
#
# ||[A:piecewiseUniform](#piecewiseUniform)|[A:singleParticle](#singleParticle)|[A:noInteractions](#noInteractions)|[A:prescribedFields](#prescribedFields)|[A:twoDMotion](#twoDMotion)|[A:bPerpPlane](#bPerpPlane)|[A:eAxisAligned](#eAxisAligned)|[A:rectRegions](#rectRegions)|[A:gridLayout](#gridLayout)|[A:lineDetector](#lineDetector)|[A:fullDetection](#fullDetection)|[A:lorentzOnly](#lorentzOnly)|
# |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |
# |[A:piecewiseUniform](#piecewiseUniform)|||||||||||||
# |[A:singleParticle](#singleParticle)|||||||||||||
# |[A:noInteractions](#noInteractions)||X|||||||||||
# |[A:prescribedFields](#prescribedFields)|||||||||||||
# |[A:twoDMotion](#twoDMotion)|||||||||||||
# |[A:bPerpPlane](#bPerpPlane)|||||X||||||||
# |[A:eAxisAligned](#eAxisAligned)|||||X||||||||
# |[A:rectRegions](#rectRegions)|||||||||||||
# |[A:gridLayout](#gridLayout)||||||||X|||||
# |[A:lineDetector](#lineDetector)|||||||||||||
# |[A:fullDetection](#fullDetection)|||||||||||||
# |[A:lorentzOnly](#lorentzOnly)|||||||||||||
#
#
# <a id="Table:TraceMatAvsAll"></a>
#
# ||[A:piecewiseUniform](#piecewiseUniform)|[A:singleParticle](#singleParticle)|[A:noInteractions](#noInteractions)|[A:prescribedFields](#prescribedFields)|[A:twoDMotion](#twoDMotion)|[A:bPerpPlane](#bPerpPlane)|[A:eAxisAligned](#eAxisAligned)|[A:rectRegions](#rectRegions)|[A:gridLayout](#gridLayout)|[A:lineDetector](#lineDetector)|[A:fullDetection](#fullDetection)|[A:lorentzOnly](#lorentzOnly)|
# |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |
# |[DD:qOverm](#DD:qOverm)|||||||||||||
# |[DD:initState](#DD:initState)|||||||||||||
# |[DD:eField](#DD:eField)||||X|||X||||||
# |[DD:bField](#DD:bField)||||X||X|||||||
# |[DD:regionRect](#DD:regionRect)||||||||X|X||||
# |[DD:fieldsByRegion](#DD:fieldsByRegion)|X|||X|||||||||
# |[DD:detectorLine](#DD:detectorLine)||||||||||X|||
# |[TM:velocity](#TM:velocity)|||||||||||||
# |[TM:acceleration](#TM:acceleration)|||||||||||||
# |[TM:lorentzForce](#TM:lorentzForce)||X||X|||||||||
# |[TM:eqnMotion](#TM:eqnMotion)||X||X||||||||X|
# |[GD:kin2D](#GD:kin2D)|||||X||||||||
# |[GD:vCrossB2D](#GD:vCrossB2D)|||||X|X|||||||
# |[GD:dyn2D](#GD:dyn2D)||||X|X|X|X||||||
# |[IM:stateEvol](#IM:stateEvol)||X|X||X|||||||X|
# |[IM:detHit](#IM:detHit)||||||||||X|X||
# |[FR:Input-Values](#inputValues)|||||||||||||
# |[FR:Echo-Inputs](#echoInputs)|||||||||||||
# |[FR:Build-Region-Grid](#buildRegionGrid)|||||||||||||
# |[FR:Lookup-Active-Region](#lookupActiveRegion)|||||||||||||
# |[FR:Compute-Trajectory](#computeTraj)|||||||||||||
# |[FR:Report-Outputs](#reportOutputs)|||||||||||||
# |[NFR:Correctness](#correct)|||||||||||||
# |[NFR:Maintainability](#maintainable)|||||||||||||
# |[NFR:Portability](#portable)|||||||||||||
# |[LC:lcExtendTo3D](#lcExtendTo3D)|||||X||||||||
# |[UC:ucLorentzForce](#ucLorentzForce)||||||||||||X|
#
#
# <a id="Table:TraceMatRefvsRef"></a>
#
# ||[DD:qOverm](#DD:qOverm)|[DD:initState](#DD:initState)|[DD:eField](#DD:eField)|[DD:bField](#DD:bField)|[DD:regionRect](#DD:regionRect)|[DD:fieldsByRegion](#DD:fieldsByRegion)|[DD:detectorLine](#DD:detectorLine)|[TM:velocity](#TM:velocity)|[TM:acceleration](#TM:acceleration)|[TM:lorentzForce](#TM:lorentzForce)|[TM:eqnMotion](#TM:eqnMotion)|[GD:kin2D](#GD:kin2D)|[GD:vCrossB2D](#GD:vCrossB2D)|[GD:dyn2D](#GD:dyn2D)|[IM:stateEvol](#IM:stateEvol)|[IM:detHit](#IM:detHit)|
# |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |
# |[DD:qOverm](#DD:qOverm)|||||||||||||||||
# |[DD:initState](#DD:initState)|||||||||||||||||
# |[DD:eField](#DD:eField)|||||||||||||||||
# |[DD:bField](#DD:bField)|||||||||||||||||
# |[DD:regionRect](#DD:regionRect)|||||||||||||||||
# |[DD:fieldsByRegion](#DD:fieldsByRegion)|||||X||||||||||||
# |[DD:detectorLine](#DD:detectorLine)|||||||||||||||||
# |[TM:velocity](#TM:velocity)|||||||||||||||||
# |[TM:acceleration](#TM:acceleration)|||||||||||||||||
# |[TM:lorentzForce](#TM:lorentzForce)|||||||||||||||||
# |[TM:eqnMotion](#TM:eqnMotion)||||||||||X|||||||
# |[GD:kin2D](#GD:kin2D)||||||||X|||||||||
# |[GD:vCrossB2D](#GD:vCrossB2D)|||||||||||||||||
# |[GD:dyn2D](#GD:dyn2D)|X|||||||||X|X||X||||
# |[IM:stateEvol](#IM:stateEvol)|X|X||||X||||||X||X|||
# |[IM:detHit](#IM:detHit)|||||||X||||||||X||
#
#
# <a id="Table:TraceMatAllvsR"></a>
#
# ||[DD:qOverm](#DD:qOverm)|[DD:initState](#DD:initState)|[DD:eField](#DD:eField)|[DD:bField](#DD:bField)|[DD:regionRect](#DD:regionRect)|[DD:fieldsByRegion](#DD:fieldsByRegion)|[DD:detectorLine](#DD:detectorLine)|[TM:velocity](#TM:velocity)|[TM:acceleration](#TM:acceleration)|[TM:lorentzForce](#TM:lorentzForce)|[TM:eqnMotion](#TM:eqnMotion)|[GD:kin2D](#GD:kin2D)|[GD:vCrossB2D](#GD:vCrossB2D)|[GD:dyn2D](#GD:dyn2D)|[IM:stateEvol](#IM:stateEvol)|[IM:detHit](#IM:detHit)|[FR:Input-Values](#inputValues)|[FR:Echo-Inputs](#echoInputs)|[FR:Build-Region-Grid](#buildRegionGrid)|[FR:Lookup-Active-Region](#lookupActiveRegion)|[FR:Compute-Trajectory](#computeTraj)|[FR:Report-Outputs](#reportOutputs)|[NFR:Correctness](#correct)|[NFR:Maintainability](#maintainable)|[NFR:Portability](#portable)|
# |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |:--- |
# |[GS:predictTrajectory](#predictTrajectory)|||||||||||||||X|||||||||||
# |[GS:determineDetectorOutcome](#determineDetectorOutcome)||||||||||||||||X||||||||||
# |[FR:Input-Values](#inputValues)||||||||||||||||||||||||||
# |[FR:Echo-Inputs](#echoInputs)||||||||||||||||||||||||||
# |[FR:Build-Region-Grid](#buildRegionGrid)|||||X|||||||||||||||||||||
# |[FR:Lookup-Active-Region](#lookupActiveRegion)||||||X||||||||||||||||||||
# |[FR:Compute-Trajectory](#computeTraj)|||||||||||||||X|||||||||||
# |[FR:Report-Outputs](#reportOutputs)|||||||||||||||X|X||||||||||
# |[NFR:Correctness](#correct)||||||||||||||||||||||||||
# |[NFR:Maintainability](#maintainable)||||||||||||||||||||||||||
# |[NFR:Portability](#portable)||||||||||||||||||||||||||
#
#
# The purpose of the traceability graphs is also to provide easy references on what has to be additionally modified if a certain component is changed. The arrows in the graphs represent dependencies. The component at the tail of an arrow is depended on by the component at the head of that arrow. Therefore, if a component is changed, the components that it points to should also be changed. [Fig:TraceGraphAvsA](#Figure:TraceGraphAvsA) shows the dependencies of assumptions on each other. [Fig:TraceGraphAvsAll](#Figure:TraceGraphAvsAll) shows the dependencies of data definitions, theoretical models, general definitions, instance models, requirements, likely changes, and unlikely changes on the assumptions. [Fig:TraceGraphRefvsRef](#Figure:TraceGraphRefvsRef) shows the dependencies of data definitions, theoretical models, general definitions, and instance models on each other. [Fig:TraceGraphAllvsR](#Figure:TraceGraphAllvsR) shows the dependencies of requirements and goal statements on the data definitions, theoretical models, general definitions, and instance models. [Fig:TraceGraphAllvsAll](#Figure:TraceGraphAllvsAll) shows the dependencies of dependencies of assumptions, models, definitions, requirements, goals, and changes with each other.
# <a id="Figure:TraceGraphAvsA"></a>
# <figure>
# <img src="../../../../traceygraphs/trajecto/avsa.svg" alt="TraceGraphAvsA" >
# </figure>
# <a id="Figure:TraceGraphAvsAll"></a>
# <figure>
# <img src="../../../../traceygraphs/trajecto/avsall.svg" alt="TraceGraphAvsAll" >
# </figure>
# <a id="Figure:TraceGraphRefvsRef"></a>
# <figure>
# <img src="../../../../traceygraphs/trajecto/refvsref.svg" alt="TraceGraphRefvsRef" >
# </figure>
# <a id="Figure:TraceGraphAllvsR"></a>
# <figure>
# <img src="../../../../traceygraphs/trajecto/allvsr.svg" alt="TraceGraphAllvsR" >
# </figure>
# <a id="Figure:TraceGraphAllvsAll"></a>
# <figure>
# <img src="../../../../traceygraphs/trajecto/allvsall.svg" alt="TraceGraphAllvsAll" >
# </figure>
#
# For convenience, the following graphs can be found at the links below:
#
# - <a href=\"../../../../traceygraphs/trajecto/avsa.svg\">TraceGraphAvsA</a>
# - <a href=\"../../../../traceygraphs/trajecto/avsall.svg\">TraceGraphAvsAll</a>
# - <a href=\"../../../../traceygraphs/trajecto/refvsref.svg\">TraceGraphRefvsRef</a>
# - <a href=\"../../../../traceygraphs/trajecto/allvsr.svg\">TraceGraphAllvsR</a>
# - <a href=\"../../../../traceygraphs/trajecto/allvsall.svg\">TraceGraphAllvsAll</a>
#
# # Values of Auxiliary Constants
# <a id="Sec:AuxConstants"></a>
#
# There are no auxiliary constants.
#
# # References
# <a id="Sec:References"></a>
# <a id="koothoor2013"></a>
# [1]: Koothoor, Nirmitha. <em>A Document Driven Approach to Certifying Scientific Computing Software</em>. McMaster University, Hamilton, ON, Canada: 2013. Print.
# <a id="parnasClements1986"></a>
# [2]: Parnas, David L. and Clements, P. C. "A rational design process: How and why to fake it." <em>IEEE Transactions on Software Engineering</em>, vol. 12, no. 2, Washington, USA: February, 1986. pp. 251&ndash;257. Print.
# <a id="smithKoothoor2016"></a>
# [3]: Smith, W. Spencer and Koothoor, Nirmitha. "A Document-Driven Method for Certifying Scientific Computing Software for Use in Nuclear Safety Analysis." <em>Nuclear Engineering and Technology</em>, vol. 48, no. 2, April, 2016. <a href="http://www.sciencedirect.com/science/article/pii/S1738573315002582">http://www.sciencedirect.com/science/article/pii/S1738573315002582</a>. pp. 404&ndash;418.
# <a id="smithLai2005"></a>
# [4]: Smith, W. Spencer and Lai, Lei. "A new requirements template for scientific computing." <em>Proceedings of the First International Workshop on Situational Requirements Engineering Processes - Methods, Techniques and Tools to Support Situation-Specific Requirements Engineering Processes, SREP'05</em>. Edited by PJ Agerfalk, N. Kraiem, and J. Ralyte, Paris, France: 2005. pp. 107&ndash;121. In conjunction with 13th IEEE International Requirements Engineering Conference,
# <a id="smithEtAl2007"></a>
# [5]: Smith, W. Spencer, Lai, Lei, and Khedri, Ridha. "Requirements Analysis for Engineering Computation: A Systematic Approach for Improving Software Reliability." <em>Reliable Computing, Special Issue on Reliable Engineering Computation</em>, vol. 13, no. 1, February, 2007. <a href="https://doi.org/10.1007/s11155-006-9020-7">https://doi.org/10.1007/s11155-006-9020-7</a>. pp. 83&ndash;107.
# <a id="accelerationWiki"></a>
# [6]: Wikipedia Contributors. <em>Acceleration</em>. June, 2019. <a href="https://en.wikipedia.org/wiki/Acceleration">https://en.wikipedia.org/wiki/Acceleration</a>.
# <a id="velocityWiki"></a>
# [7]: Wikipedia Contributors. <em>Velocity</em>. June, 2019. <a href="https://en.wikipedia.org/wiki/Velocity">https://en.wikipedia.org/wiki/Velocity</a>.
